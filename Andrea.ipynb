# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
ALF = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\AFL.csv"
AIG = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\AIG.csv"
AON = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\AON.csv"
AXP = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\AXP.csv"
BAC = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\BAC.csv"
BBT = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\BBT.csv"
BK = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\BK.csv"
BLK = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\BLK.csv"
BKRB = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\BRK-B.csv"
C = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\C.csv"
CB = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\CB.csv"
CME = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\CME.csv"
COF = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\COF.csv"
GS = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\GS.csv"
ICE = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\ICE.csv"
JPM = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\JPM.csv"
MMC = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\MMC.csv"
MS = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\MS.csv"
PGR = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\PGR.csv"
PNC = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\PNC.csv"
SCHW = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\SCHW.csv"
SPGI = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\SPGI.csv"
TRV = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\TRV.csv"
USB = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\USB.csv"
WFC = r"C:\Users\boitz\OneDrive\Desktop\XLF_historical_data\WFC.csv"

# %%
AFL = pd.read_csv(ALF,index_col='Date')
AIG = pd.read_csv(AIG,index_col='Date')
AON = pd.read_csv(AON,index_col='Date')
AXP = pd.read_csv(AXP,index_col='Date')
BAC = pd.read_csv(BAC,index_col='Date')
BBT = pd.read_csv(BBT,index_col='Date')
BK = pd.read_csv(BK,index_col='Date')
BLK = pd.read_csv(BLK,index_col='Date')
BKRB = pd.read_csv(BKRB,index_col='Date')
C = pd.read_csv(C,index_col='Date')
CB = pd.read_csv(CB,index_col='Date')
CME = pd.read_csv(CME,index_col='Date')
COF = pd.read_csv(COF,index_col='Date')
GS = pd.read_csv(GS,index_col='Date')
ICE = pd.read_csv(ICE,index_col='Date')
JPM = pd.read_csv(JPM,index_col='Date')
MMC = pd.read_csv(MMC,index_col='Date')
MS = pd.read_csv(MS,index_col='Date')
PGR = pd.read_csv(PGR,index_col='Date')
PNC = pd.read_csv(PNC,index_col='Date')
SCHW = pd.read_csv(SCHW,index_col='Date')
SPGI = pd.read_csv(SPGI,index_col='Date')
TRV = pd.read_csv(TRV,index_col='Date')
USB = pd.read_csv(USB,index_col='Date')
WFC = pd.read_csv(WFC,index_col='Date')

# %%
AFL.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
AIG.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
AON.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
AXP.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
BAC.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
BBT.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
BK.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
BLK.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
BKRB.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
C.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
CB.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
CME.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
COF.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
GS.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
ICE.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
JPM.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
MMC.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
MS.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
PGR.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
PNC.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
SCHW.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
SPGI.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
TRV.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
USB.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)
WFC.drop(columns=['Open', 'High', 'Low', 'Volume','Adj Close','Volume'], inplace=True)

# %%
AFL = AFL.rename(columns={"Close":"AFL"})
AIG = AIG.rename(columns={"Close":"AIG"})
AON = AON.rename(columns={"Close":"AON"})
AXP = AXP.rename(columns={"Close":"AXP"})
BAC = BAC.rename(columns={"Close":"BAC"})
BBT = BBT.rename(columns={"Close":"BBT"})
BK = BK.rename(columns={"Close":"BK"})
BLK = BLK.rename(columns={"Close":"BLK"})
BKRB = BKRB.rename(columns={"Close":"BKRB"})
C = C.rename(columns={"Close":"C"})
CB = CB.rename(columns={"Close":"CB"})
CME = CME.rename(columns={"Close":"CME"})
COF = COF.rename(columns={"Close":"COF"})
GS = GS.rename(columns={"Close":"GS"})
ICE = ICE.rename(columns={"Close":"ICE"})
JPM = JPM.rename(columns={"Close":"JPM"})
MMC = MMC.rename(columns={"Close":"MMC"})
MS = MS.rename(columns={"Close":"MS"})
PGR = PGR.rename(columns={"Close":"PGR"})
PNC = PNC.rename(columns={"Close":"PNC"})
SCHW = SCHW.rename(columns={"Close":"SCHW"})
SPGI = SPGI.rename(columns={"Close":"SPGI"})
TRV = TRV.rename(columns={"Close":"TRV"})
USB = USB.rename(columns={"Close":"USB"})
WFC = WFC.rename(columns={"Close":"WFC"})

# %%
XLF = pd.concat([AFL,AIG,AON,AXP,BAC,BBT,BK,BLK,BKRB,C,CME,COF,GS,ICE,JPM,MMC,MS,PGR,PNC,SCHW,SPGI,TRV,USB,WFC],axis="columns",join="inner")

# %%
XLF.plot(figsize=(22,8))
